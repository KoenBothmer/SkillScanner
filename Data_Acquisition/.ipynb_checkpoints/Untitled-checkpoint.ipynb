# %%
import pdfplumber
import pandas as pd
from sentence_transformers import SentenceTransformer, util
import pickle
import numpy as np

# %%
#dfs = tabula.read_pdf("Modulhandbuch_FS-MADS-60_Data-Science_SGo_19.09.2019.pdf", pages='all', multiple_tables=True)
pdf = pdfplumber.open("Modulhandbuch_FS-MADS-60_Data-Science_SGo_19.09.2019.pdf")
pages = pdf.pages[0:]
#page.extract_table()

# %%
for page in pages[:10]:
    print(page.extract_text())
    print("---------------------")
    print(page.extract_table())
# Out:
#
# Module Handbook
# Master Program
# Data Science
# 60 ECTS
# Master of Science (M.Sc.)
# Distance Learning
# Modulhandbuch_FI-MADS-60_Data Science_SGo_19.09.2019
# 1/78
# ---------------------
# None
# This module handbook contains information about the topical issues and the organisation of
# the Master Program “Master Data Science“ (60 ECTS)”.
# In particular, it contains
#   Administrative facts
#   module-/course number
#   module-/course titles
#   duration of modules/courses
#   ECTS-credits
#   Module director
#   Academic approaches
#   type of lecture
#   prerequisites, topical links to other modules
#   language of instruction
#    course objectives
#   course content, course literature, instructional methods
#   Student affairs
#   course outcomes
#   workload structured by contact hours and individual studies
#   Examination issues
#   number and type of assessments
#   requirements for participation in final assessments
#   modular weightings within the final master mark
#
# 2/78
# ---------------------
# None
# Contents
# Module DLMDSAS Advanced Statistics ........................................................... 5
# Module Description ................................................................................................................ 6
# Advanced Statistics ............................................................................................................ 8
# Module DLMDSUCE Use Case and Evaluation ................................................ 11
# Module Description .............................................................................................................. 12
# Use Case and Evaluation .................................................................................................. 14
# Module DLMDSSCTDS Seminar: Current Topics in Data Science .................... 17
# Module Description .............................................................................................................. 18
# Seminar: Current Topics in Data Science ......................................................................... 20
# Module DLMDSML Machine Learning ........................................................... 22
# Module Description .............................................................................................................. 23
# Machine Learning ............................................................................................................. 25
# Module DLMDSDL Deep Learning .................................................................. 28
# Module Description .............................................................................................................. 29
# Deep Learning .................................................................................................................. 31
# Module DLMDSME Case Study: Model Engineering ....................................... 34
# Module Description .............................................................................................................. 35
# Case Study: Model Engineering ....................................................................................... 37
# Electives ........................................................................................................ 40
# Module DLMDSEBDSE Big Data and Software Engineering ............................ 41
# Module Description .............................................................................................................. 42
# Big Data Technologies ...................................................................................................... 45
# Software Engineering for Data-Intensive Sciences .......................................................... 48
# Module DLMDSESMMI Smart Manufacturing Methods and Industrial
# Automation ................................................................................................... 51
# Module Description .............................................................................................................. 52
# Manufacturing Methods Industry 4.0 .............................................................................. 55
# Industrial Automation ...................................................................................................... 58
# Applied Autonomous Driving ........................................................................ 62
# Module Description .............................................................................................................. 63
# Architectures of Self-Driving Vehicles .............................................................................. 66
# 3/78
# ---------------------
# None
# Case Study: Localization, Motion Planning, and Sensor Fusion ....................................... 69
# Module DLMMTHE Master Thesis ................................................................. 72
# Module Description .............................................................................................................. 73
# Master Thesis ................................................................................................................... 75
# Thesis Defense.................................................................................................................. 77
#
#
# 4/78
# ---------------------
# None
#
#
#
# Module DLMDSAS
# Advanced Statistics
# 5 ECTS
#
#
#
# Minimum duration of the module:   1 semester
#
# Admission requirements:     Advanced Mathematics (DLMDSAM01)
#
# 5/78
# ---------------------
# None
# Module Description
#
# Module Title:  Advanced Statistics
# Module No.:  Semester / Term:  Duration:
# DLMDSAS  1st semester  Minimum 1 semester
# Module Type(s):  Compulsory  Regularly Offered in:
# WS / SS
# Workload: 150 h  Credit Points: 5
# Admission Requirements:  Language of Instruction:
#   Advanced Mathematics (DLMDSAM01)  English
# Contributing Courses to Module:  Workload:
#   Advanced Statistics (DLMDSAS01)  Self-study: 90 h
# Self-examination: 30 h
# Tutorials: 30 h
# Course Coordinator(s) / Tutor(s):  Module Director:
# Please see the current list of tutors on the Learning  Prof. Dr. Marco de Pinto
# Management System.
# References to Other Programs:  References to Other Modules in
# the Program:
#   Master Artificial Intelligence (120 ECTS)
#   Advanced Statistics
#   Deep Learning
# 6/78
# ---------------------
# [['Module Title:', 'Advanced Statistics', None], ['Module No.: \nDLMDSAS', 'Semester / Term: \n1st semester', 'Duration:  \nMinimum 1 semester'], ['Module Type(s):', 'Compulsory', 'Regularly Offered in: \nWS / SS'], ['Workload: 150 h', None, 'Credit Points: 5'], ['Admission Requirements: \n\uf0a7  Advanced Mathematics (DLMDSAM01)', None, 'Language of Instruction: \nEnglish'], ['Contributing Courses to Module: \n\uf0a7  Advanced Statistics (DLMDSAS01)', None, 'Workload: \nSelf-study: 90 h \nSelf-examination: 30 h \nTutorials: 30 h'], ['Course Coordinator(s) / Tutor(s): \nPlease see the current list of tutors on the Learning \nManagement System.', None, 'Module Director: \nProf. Dr. Marco de Pinto'], ['References to Other Programs: \n\uf0a7  Master Artificial Intelligence (120 ECTS)', None, 'References to Other Modules in \nthe Program: \n\uf0a7  Advanced Statistics \n\uf0a7  Deep Learning']]
# Qualification and Educational Objectives of the Module:
# On successful completion of this module, students will be able to:
#   understand the fundamental building blocks of statistics.
#   analyze stochastic data in terms of the underlying probability distributions.
#   utilize Bayesian statistics techniques.
#   summarize the properties of observed data using descriptive statistics.
#   apply data visualization techniques to illustrate the behavior of observed data.
#   evaluate model parameters using parameter estimation techniques.
#   create hypothesis tests to discriminate between several model classes.
# Learning Content of the Module:
#   Introduction to statistics
#   Important probability distributions and their applications
#   Bayesian statistics
#   Descriptive statistics
#   Data visualization
#   Parameter estimation
#   Hypothesis tests
# Teaching Methods:  See the contributing course outline
# Literature:  See the contributing course outline
# Percentage of the Module  Prerequisites to Qualify for  Assessment:
# Grade Relative to the Final  Assessment:
# Grade for the Program:
# 5 ECTS of 60 ECTS =   See course outline  DLMDSAS01:
# 8.33%
# Exam, 90 min. (100%)
#
# 7/78
# ---------------------
# [['Qualification and Educational Objectives of the Module: \nOn successful completion of this module, students will be able to: \n\uf0a7  understand the fundamental building blocks of statistics. \n\uf0a7  analyze stochastic data in terms of the underlying probability distributions. \n\uf0a7  utilize Bayesian statistics techniques. \n\uf0a7  summarize the properties of observed data using descriptive statistics. \n\uf0a7  apply data visualization techniques to illustrate the behavior of observed data. \n\uf0a7  evaluate model parameters using parameter estimation techniques. \n\uf0a7  create hypothesis tests to discriminate between several model classes.', None, None], ['Learning Content of the Module: \n\uf0a7  Introduction to statistics \n\uf0a7  Important probability distributions and their applications \n\uf0a7  Bayesian statistics \n\uf0a7  Descriptive statistics \n\uf0a7  Data visualization \n\uf0a7  Parameter estimation \n\uf0a7  Hypothesis tests', None, None], ['Teaching Methods:  See the contributing course outline', None, None], ['Literature:  See the contributing course outline', None, None], ['Percentage of the Module \nGrade Relative to the Final \nGrade for the Program:  \n5 ECTS of 60 ECTS =  \n8.33%', 'Prerequisites to Qualify for \nAssessment: \nSee course outline', 'Assessment:  \nDLMDSAS01: \nExam, 90 min. (100%)']]
# Course No.:  Course Title:  Hours Total: 150
# DLMDSAS01  Advanced Statistics
# Credit Points: 5
# Course Type: Compulsory  Admission Requirements:
# Course Availability: In each semester  Please see module description.
# Course Duration: Minimum 1 semester
# Course Coordinator / Instructor:  References to Other Modules:
# See current list of tutors in the Learning
# Please see module description.
# Management System.
# Course Description:
# Nearly all processes in nature and technical or scientific scenarios are not deterministic but
# stochastic. Therefore, these processes must be described in terms of probabilities and
# probability density distributions.
# After defining and introducing the fundamental concepts of statistics, the course will cover
# important probability distributions and their prevalence in application scenarios; discuss
# descriptive techniques to summarize and visualize data effectively; and discuss the Bayesian
# approach to statistics.
# Estimating parameters is a key ingredient in optimizing data models, and the course will
# give a thorough overview of the most important techniques.
# Hypothesis testing is a crucial aspect in establishing the observation of new effects and
# determination of the significance of statistical effects. Special focus will be given to the
# correct interpretation of p-Values and the correct procedure for multiple hypothesis tests.
# Course Objectives and Outcome:
# On successful completion of this course, students will be able to:
#   understand the fundamental building blocks of statistics.
#   analyze stochastic data in terms of the underlying probability distributions.
#   utilize Bayesian statistics techniques.
#   summarize the properties of observed data using descriptive statistics.
#   apply data visualization techniques to design graphics that illustrate the behavior of
# observed data.
#   evaluate model parameters using parameter estimation techniques.
#   create hypothesis tests to discriminate between several model classes.
# 8/78
# ---------------------
# [['Course No.: \nDLMDSAS01', 'Course Title: \nAdvanced Statistics', 'Hours Total: 150'], [None, None, 'Credit Points: 5'], ['Course Type: Compulsory \nCourse Availability: In each semester \nCourse Duration: Minimum 1 semester', None, 'Admission Requirements: \nPlease see module description.'], ['Course Coordinator / Instructor: \nSee current list of tutors in the Learning \nManagement System.', None, 'References to Other Modules: \nPlease see module description.'], ['Course Description: \nNearly all processes in nature and technical or scientific scenarios are not deterministic but \nstochastic. Therefore, these processes must be described in terms of probabilities and \nprobability density distributions. \nAfter defining and introducing the fundamental concepts of statistics, the course will cover \nimportant probability distributions and their prevalence in application scenarios; discuss \ndescriptive techniques to summarize and visualize data effectively; and discuss the Bayesian \napproach to statistics. \nEstimating parameters is a key ingredient in optimizing data models, and the course will \ngive a thorough overview of the most important techniques. \nHypothesis testing is a crucial aspect in establishing the observation of new effects and \ndetermination of the significance of statistical effects. Special focus will be given to the \ncorrect interpretation of p-Values and the correct procedure for multiple hypothesis tests.', None, None], ['Course Objectives and Outcome: \nOn successful completion of this course, students will be able to: \n\uf0a7  understand the fundamental building blocks of statistics. \n\uf0a7  analyze stochastic data in terms of the underlying probability distributions. \n\uf0a7  utilize Bayesian statistics techniques. \n\uf0a7  summarize the properties of observed data using descriptive statistics. \n\uf0a7  apply data visualization techniques to design graphics that illustrate the behavior of \nobserved data. \n\uf0a7  evaluate model parameters using parameter estimation techniques. \n\uf0a7  create hypothesis tests to discriminate between several model classes.', None, None]]
# Teaching Methods:
# The learning materials include printed and online course books, vodcasts, online
# knowledge tests, podcasts, online tutorials, and case studies. This range of learning
# materials is offered to students so they can study at a time, place, and pace that best suits
# their circumstances and individual learning style.
# Course Content:
# 1.  Introduction to Statistics
# 1.1. Random Variables
# 1.2. Kolmogorov Axioms
# 1.3. Probability Distributions
# 1.4. Decomposing probability distributions
# 1.5. Expectation Values and Moments
# 1.6. Central Limit Theorem
# 1.7. Sufficient Statistics
# 1.8. Problems of Dimensionality
# 1.9. Component Analysis and Discriminants
# 2.  Important Probability Distributions and their Applications
# 2.1. Binomial Distribution
# 2.2. Gauss or Normal Distribution
# 2.3. Poisson and Gamma-Poisson Distribution
# 2.4. Weibull Distribution
# 3.  Bayesian Statistics
# 3.1. Bayes’ Rule
# 3.2. Estimating the Prior, Benford’s Law, Jeffry’s Rule
# 3.3. Conjugate Prior
# 3.4. Bayesian & Frequentist Approach
# 4.  Descriptive Statistics
# 4.1. Mean, Median, Mode, Quantiles
# 4.2. Variance, Skewness, Kurtosis
# 5.  Data Visualization
# 5.1. General Principles of Dataviz/Visual Communication
# 5.2. 1D, 2D Histograms
# 5.3. Box Plot, Violin Plot
# 5.4. Scatter Plot, Scatter Plot Matrix, Profile Plot
# 5.5. Bar Chart
# 6.  Parameter Estimation
# 6.1. Maximum Likelihood
# 6.2. Ordinary Least Squares
# 6.3. Expectation Maximization (EM)
# 6.4. Lasso and Ridge Regularization
# 6.5. Propagation of Uncertainties
# 7.  Hypothesis Test
# 7.1. Error of 1st and 2nd Kind
# 7.2. Multiple Hypothesis Tests
# 7.3. p-Value
# 9/78
# ---------------------
# [['Teaching Methods: \nThe learning materials include printed and online course books, vodcasts, online \nknowledge tests, podcasts, online tutorials, and case studies. This range of learning \nmaterials is offered to students so they can study at a time, place, and pace that best suits \ntheir circumstances and individual learning style.'], ['Course Content: \n1.  Introduction to Statistics \n1.1. Random Variables \n1.2. Kolmogorov Axioms \n1.3. Probability Distributions \n1.4. Decomposing probability distributions \n1.5. Expectation Values and Moments \n1.6. Central Limit Theorem \n1.7. Sufficient Statistics \n1.8. Problems of Dimensionality \n1.9. Component Analysis and Discriminants \n2.  Important Probability Distributions and their Applications \n2.1. Binomial Distribution \n2.2. Gauss or Normal Distribution \n2.3. Poisson and Gamma-Poisson Distribution \n2.4. Weibull Distribution \n3.  Bayesian Statistics \n3.1. Bayes’ Rule \n3.2. Estimating the Prior, Benford’s Law, Jeffry’s Rule \n3.3. Conjugate Prior \n3.4. Bayesian & Frequentist Approach \n4.  Descriptive Statistics \n4.1. Mean, Median, Mode, Quantiles \n4.2. Variance, Skewness, Kurtosis \n5.  Data Visualization \n5.1. General Principles of Dataviz/Visual Communication \n5.2. 1D, 2D Histograms \n5.3. Box Plot, Violin Plot \n5.4. Scatter Plot, Scatter Plot Matrix, Profile Plot \n5.5. Bar Chart \n6.  Parameter Estimation \n6.1. Maximum Likelihood \n6.2. Ordinary Least Squares \n6.3. Expectation Maximization (EM) \n6.4. Lasso and Ridge Regularization \n6.5. Propagation of Uncertainties \n7.  Hypothesis Test \n7.1. Error of 1st and 2nd Kind \n7.2. Multiple Hypothesis Tests \n7.3. p-Value']]
# Literature:
#   Bishop, C. (2007). Pattern recognition and machine learning (2nd ed.). Singapore:
# Springer.
#   Bruce, P., & Bruce, A. (2017). Statistics for data scientists: 50 essential concepts.
# Sebastopol, CA: O’Reilley Publishing.
#   Downey, A. (2013). Think Bayes. Sebastopol, CA: O’Reilley Publishing.
#   Downey, A. (2014). Think stats. Sebastopol, CA: O’Reilley Publishing.
#   McKay, D. (2003). Information theory, inference and learning algorithms. Cambridge:
# Cambridge University Press.
#   Reinhart, A. (2015). Statistics done wrong. San Francisco, CA: No Starch Press.
# A current list with course-specific compulsory reading, as well as references to further
# literature, is stored in the Learning Management System.
# Prerequisites to Qualify    Depending on the course: Completion of online
# for Assessment:
# knowledge tests (approx. 15 minutes per unit,  X
# pass / not pass)
# Assessment:    Exam, 90 min.
# Student Workload  Self-study: 90
# (in hours): 150  Self-testing: 30
# Tutorials: 30
#
# 10/78
# ---------------------
# [['Literature: \n\uf0a7  Bishop, C. (2007). Pattern recognition and machine learning (2nd ed.). Singapore: \nSpringer. \n\uf0a7  Bruce, P., & Bruce, A. (2017). Statistics for data scientists: 50 essential concepts. \nSebastopol, CA: O’Reilley Publishing. \n\uf0a7  Downey, A. (2013). Think Bayes. Sebastopol, CA: O’Reilley Publishing. \n\uf0a7  Downey, A. (2014). Think stats. Sebastopol, CA: O’Reilley Publishing. \n\uf0a7  McKay, D. (2003). Information theory, inference and learning algorithms. Cambridge: \nCambridge University Press. \n\uf0a7  Reinhart, A. (2015). Statistics done wrong. San Francisco, CA: No Starch Press. \nA current list with course-specific compulsory reading, as well as references to further \nliterature, is stored in the Learning Management System.'], ['Prerequisites to Qualify  \uf0a7  Depending on the course: Completion of online   \nfor Assessment: \nknowledge tests (approx. 15 minutes per unit,  X \npass / not pass)'], ['Assessment:  \uf0a7  Exam, 90 min.'], ['Student Workload  Self-study: 90 \n(in hours): 150  Self-testing: 30 \nTutorials: 30']]

# %%
long_string = ""
for page in pages:
    long_string+=page.extract_text()

# %%
for module in long_string.split('Module Title:  '): #getting full text of each module
    course_objectives = module.split('On successful completion of this course, students will be able to: ')
    if len(course_objectives)>1: #avoid empty strings
        
        #Module title
        module_title = module.split('\n')[0]
        
        #Module objtectives
        objectives = course_objectives[1]
        objectives = objectives.split('Teaching Methods')[0]
        if (objectives[-4:]) =='/78 ':
            objectives = objectives[:-6]
        objectives = objectives.encode()
        objectives = objectives.decode()
        objectives = objectives.replace('\n',"")
        objectives = objectives.replace('. ',".")
        objectives = objectives.split('\uf0a7  ')[1:] #[0] is always empty because of the splitting
        
        #Course Content
        content = module.split('Course Content: ')[1].split('Literature')[0]
        if (content[-4:]) =='/78 ':
            content = content[:-6]
        content = content.split('\n')
        content = content[1:-1] #[0] and [:-0] are always empty because of the splitting
    print(module_title)
    print(objectives)
    print(content)
    print('==============')
# Out:
# Applied Autonomous Driving
# ['explain and recognize the main components of a self-driving car.', 'distinguish the sensor solutions for a self-driving car and adopt the best one for a given scenario.', 'model and implement a simple motion control system.', 'manage the main communication protocols to retrieve valuable information.', 'reflect on the social impact of self-driving cars. ']
# ['1.  Introduction ', '1.1. Basic concepts and key technologies ', '1.2. Hardware overview ', '1.3. Software overview ', '1.4. State of the art and open challenges ', '1.5. Trends ', '2.  Environment Perception ', '2.1. Basic concepts ', '2.2. GPS ', '2.3. Inertial sensors ', '2.4. Lidar and Radar ', '2.5. Cameras ', '3.  Moving, Braking, Steering ', '3.1. Fundamentals ', '3.2. Dynamics of a mobile vehicle ', '3.3. Braking technologies ', '3.4. Lateral and longitudinal control ', '3.5. Safety issues ', '4.  Communication ', '4.1. Car2X communication ', '4.2. Protocols ', '4.3. Safety issues ', '5.  Social Impact ', '5.1. Ethics for autonomous vehicles ', '5.2. New mobility ', '5.3. Autonomous vehicles and design ']
# ==============
# Advanced Statistics
# ['understand the fundamental building blocks of statistics.', 'analyze stochastic data in terms of the underlying probability distributions.', 'utilize Bayesian statistics techniques.', 'summarize the properties of observed data using descriptive statistics.', 'apply data visualization techniques to design graphics that illustrate the behavior of observed data.', 'evaluate model parameters using parameter estimation techniques.', 'create hypothesis tests to discriminate between several model classes.']
# ['1.  Introduction to Statistics ', '1.1. Random Variables ', '1.2. Kolmogorov Axioms ', '1.3. Probability Distributions ', '1.4. Decomposing probability distributions ', '1.5. Expectation Values and Moments ', '1.6. Central Limit Theorem ', '1.7. Sufficient Statistics ', '1.8. Problems of Dimensionality ', '1.9. Component Analysis and Discriminants ', '2.  Important Probability Distributions and their Applications ', '2.1. Binomial Distribution ', '2.2. Gauss or Normal Distribution ', '2.3. Poisson and Gamma-Poisson Distribution ', '2.4. Weibull Distribution ', '3.  Bayesian Statistics ', '3.1. Bayes’ Rule ', '3.2. Estimating the Prior, Benford’s Law, Jeffry’s Rule ', '3.3. Conjugate Prior ', '3.4. Bayesian & Frequentist Approach ', '4.  Descriptive Statistics ', '4.1. Mean, Median, Mode, Quantiles ', '4.2. Variance, Skewness, Kurtosis ', '5.  Data Visualization ', '5.1. General Principles of Dataviz/Visual Communication ', '5.2. 1D, 2D Histograms ', '5.3. Box Plot, Violin Plot ', '5.4. Scatter Plot, Scatter Plot Matrix, Profile Plot ', '5.5. Bar Chart ', '6.  Parameter Estimation ', '6.1. Maximum Likelihood ', '6.2. Ordinary Least Squares ', '6.3. Expectation Maximization (EM) ', '6.4. Lasso and Ridge Regularization ', '6.5. Propagation of Uncertainties ', '7.  Hypothesis Test ', '7.1. Error of 1st and 2nd Kind ', '7.2. Multiple Hypothesis Tests ']
# ==============
# Use Case and Evaluation
# ['analyze use cases and their requirements regarding the project objectives.', 'apply common metrics to evaluate predictions. ', 'evaluate key performance indicators to asses projects from a business perspective.', 'create monitoring tools that can be used to constantly evaluate the status quo of a project. ', 'understand common fallacies and how to avoid them.']
# ['1.  Use Case Evaluation ', '1.1. Identification of Use Cases ', '1.2. Specifying Use Case Requirements ', '1.3. Data Sources and Data Handling Classification ', '2.  Model-centric Evaluation ', '2.1. Common Metrics for Regression and Classification ', '2.2. Visual Aides ', '3.  Business-centric Evaluation ', '3.1. Cost Function and Optimal Point Estimators ', '3.2. Evaluation Using KPIs ', '3.3. A/B Test ', '4.  Monitoring ', '4.1. Visual Monitoring Using Dashboards ', '4.2. Automated Reporting and Alerting ', '5.  Avoiding Common Fallacies ', '5.1. Cognitive Biases ', '5.2. Statistical Effects ', '5.3. Change Management: Transformation to a Data-driven Company ']
# ==============
# Seminar: Current Topics in Data Science
# ['identify current research trends and topics in data science.', 'outline a selected topic in the form of a written essay.', 'explain relevant assumptions and design choices pertaining to the topic of choice.', 'relate the chosen topic to comparable approaches.', "name and describe potential applications for the chosen topic's concepts."]
# ['The seminar covers current topics in data science. Each participant must write a seminar ', 'paper on a topic assigned to him/her. ']
# ==============
# Machine Learning
# ['know different machine learning model classes.', 'comprehend the difference between supervised, unsupervised, and reinforcement learning methods.', 'understand common machine learning models.', 'analyze trade-offs in the application of different models.', 'appropriately choose machine learning models according to a given task.']
# ['1.  Introduction to Machine Learning  ', '1.1. Regression & Classification  ', '1.2. Supervised & Unsupervised Learning  ', '1.3. Reinforcement Learning  ', '2.  Clustering  ', '2.1. Introduction to clustering ', '2.2. K-Means  ', '2.3. Expectation Maximization  ', '2.4. DBScan  ', '2.5. Hierarchical Clustering  ', '3.  Regression  ', '3.1. Linear & Non-linear Regression  ', '3.2. Logistic Regression  ', '3.3. Quantile Regression  ', '3.4. Multivariate Regression  ', '3.5. Lasso & Ridge Regression ', '4.  Support Vector Machines  ', '4.1. Introduction to Support Vector Machines ', '4.2. SVM for Classification ', '4.3. SVM for Regression  ', '5.  Decision Trees  ', '5.1. Introduction to Decision Trees ', '5.2. Decision Trees for Classification  ', '5.3. Decision Trees for Regression ', '6.  Genetic Algorithms ', '6.1. Introduction to Genetic Algorithms ', '6.2. Applications of Genetic Algorithms ']
# ==============
# Deep Learning
# ['comprehend the fundamental building blocks of neural networks. ', 'understand concepts in deep learning.', 'analyze the relevant deep learning architecture in a wide range of application scenarios.', 'create deep learning models.', 'utilize alternative methods to train deep learning models.']
# ['1.  Introduction to Neural Network and Deep Learning ', '1.1.  The Biological Brain ', '1.2.  Perceptron and Multi-Layer Perceptrons ', '2.  Network Architectures ', '2.1.   Feed-Forward Networks ', '2.2.   Convolutional Networks ', '2.3.   Recurrent Networks, Memory Cells and LSTMs ', '3.  Neural Network Training ', '3.1.  Weight Initialization and Transfer Function ', '3.2.  Backpropagation and Gradient Descent ', '3.3.  Regularization and Overtraining ', '4.  Alternative Training Methods ', '4.1.  Attention ', '4.2.  Feedback Alignment ', '4.3.  Synthetic Gradients ', '4.4.  Decoupled Network Interfaces ', '5.  Further Network Architectures ', '5.1.  Generative Adversarial Networks ', '5.2.  Autoencoders ', '5.3.  Restricted Boltzmann Machines ', '5.4.  Capsule Networks ', '5.5.  Spiking Networks ', ' ']
# ==============
# Case Study: Model Engineering
# ['understand current data science methodologies.', 'devaluate the quality of the data used in data science projects.', 'create new features from raw data.', 'apply feature selection techniques.', 'make predictive models using data science techniques.', 'identify common fallacies and know how to avoid them.']
# ['1.  Data Science Methodologies ', '1.1. CRISP-DM ', '1.2. MS Team Data Science ', '2.  Data Quality ', '2.1. Evaluating data quality ', '2.2. Using low quality data ', '2.3. Data duality and domain knowledge ', '3.  Feature Engineering ', '3.1.  Building new features ', '3.2.  Splitting variables ', '3.3.  Feature engineering exploiting domain knowledge ', '4.  Feature Selection ', '4.1.  Univariate feature selection ', '4.2.  Model based feature selection ', '5.  Building a Predictive Model ', '5.1.  Establishing a benchmark model  ', '5.2.  Prediction as probabilities ', '5.3.  Interpretable machine learning and results ', '6.  Avoiding Common Fallacies ', '6.1.  Overtraining & generalization ', '6.2.  Overfitting & Occam’s Razor ', '6.3.  Workflow automation and model persistence ', ' ', '   ']
# ==============
# Big Data and Software Engineering
# ['identify the different types and sources of data.', 'understand different database concepts.', 'build new database structures.', 'evaluate various data storage frameworks w.r.t.project requirements.', 'analyze which data format to use for a given project.', 'create a distributed computing environment for a given project.']
# ['1.  Data Types and Data Sources ', '1.1. The 4Vs of data: volume, velocity, variety, veracity ', '1.2. Data sources ', '1.3. Data types ', '2.  Databases ', '2.1. Database structures ', '2.2. Introduction to SQL ', '2.3. Relational databases ', '2.4. nonSQL, NewSQL databases ', '2.5. Timeseries DB  ', '3.  Modern data storage frameworks ', '3.1. Distributed Filesystems  ', '3.2. Streaming frameworks ', '3.3. Query frameworks ', '4.  Data formats ', '4.1. Traditional data exchange formats ', '4.2. Apache Arrow ', '4.3. Apache Parquet ', '5.  Distributed Computing ', '5.1. Cluster-based approaches ', '5.2. Containers ', '5.3. Cloud-based approaches ', '   ']
# ==============
# Smart Manufacturing Methods and Industrial Automation
# ['evaluate different manufacturing methods against given product and process requirements.', 'define and design modern additive techniques in contrast to traditional manufacturing.', 'assess and estimate the impact of current trends on manufacturing like cyber-physical systems to given manufacturing challenges and practical problems.', 'apply  modern  processes  like  rapid  prototyping,  rapid  tooling,  and  direct manufacturing.']
# ['1.  Introduction to Manufacturing Methods ', '1.1. Basic Concepts ', '1.2. Historical Development of Manufacturing ', '1.3. About the Long Tail ', '2.  Manufacturing Methods ', '2.1. Casting and Molding ', '2.2. Shaping ', '2.3. Machining ', '2.4. Joining ', '2.5. Coating ', '3.  Additive Manufacturing and 3D printing ', '3.1. Basics and Legal Aspects ', '3.2. Material Extrusion ', '3.3. Vat Polymerization ', '3.4. Powder Bed Fusion ', '3.5. Material Jetting ', '3.6. Binder Jetting ', '3.7. Direct Energy Deposition ', '3.8. Sheet Lamination ', '4.  Rapid Prototyping ', '4.1. Definitions ', '4.2. Strategical and Operative Aspects ', '4.3. Application Scenarios ', '5.  Rapid Tooling ', '5.1. Definitions ', '5.2. Direct and Indirect Methods ', '5.3. Application Scenarios ', '6.  Direct/Rapid Manufacturing ', '6.1. Potentials and Requirements ', '6.2. Implementation Examples ', '7.  Cyber-Physical Production Systems ', '7.1. Introduction ', '7.2. Cyber-Physical Production Systems ', '7.3. Impact on Design and Maintenance of Plants ', '7.4. Dynamic Reconfiguration of Plants ', '7.5. Application Examples ', '   ']
# ==============
# Applied Autonomous Driving
# ['explain and recognize the main components of a self-driving car.', 'distinguish the sensor solutions for a self-driving car and adopt the best one for a given scenario.', 'model and implement a simple motion control system.', 'manage the main communication protocols to retrieve valuable information.', 'reflect on the social impact of self-driving cars. ']
# ['1.  Introduction ', '1.1. Basic concepts and key technologies ', '1.2. Hardware overview ', '1.3. Software overview ', '1.4. State of the art and open challenges ', '1.5. Trends ', '2.  Environment Perception ', '2.1. Basic concepts ', '2.2. GPS ', '2.3. Inertial sensors ', '2.4. Lidar and Radar ', '2.5. Cameras ', '3.  Moving, Braking, Steering ', '3.1. Fundamentals ', '3.2. Dynamics of a mobile vehicle ', '3.3. Braking technologies ', '3.4. Lateral and longitudinal control ', '3.5. Safety issues ', '4.  Communication ', '4.1. Car2X communication ', '4.2. Protocols ', '4.3. Safety issues ', '5.  Social Impact ', '5.1. Ethics for autonomous vehicles ', '5.2. New mobility ', '5.3. Autonomous vehicles and design ']
# ==============
# Applied Autonomous Driving
# ['explain and recognize the main components of a self-driving car.', 'distinguish the sensor solutions for a self-driving car and adopt the best one for a given scenario.', 'model and implement a simple motion control system.', 'manage the main communication protocols to retrieve valuable information.', 'reflect on the social impact of self-driving cars. ']
# ['1.  Introduction ', '1.1. Basic concepts and key technologies ', '1.2. Hardware overview ', '1.3. Software overview ', '1.4. State of the art and open challenges ', '1.5. Trends ', '2.  Environment Perception ', '2.1. Basic concepts ', '2.2. GPS ', '2.3. Inertial sensors ', '2.4. Lidar and Radar ', '2.5. Cameras ', '3.  Moving, Braking, Steering ', '3.1. Fundamentals ', '3.2. Dynamics of a mobile vehicle ', '3.3. Braking technologies ', '3.4. Lateral and longitudinal control ', '3.5. Safety issues ', '4.  Communication ', '4.1. Car2X communication ', '4.2. Protocols ', '4.3. Safety issues ', '5.  Social Impact ', '5.1. Ethics for autonomous vehicles ', '5.2. New mobility ', '5.3. Autonomous vehicles and design ']
# ==============

# %%
def extract_objective_df(pdf):
    df = pd.DataFrame(columns = ['objective','module','study_program'])
    pages = pdf.pages[0:]
    long_string = ""
    for page in pages:
        long_string+=page.extract_text()
    for module in long_string.split('Module Title:  '): #getting full text of each module
        course_objectives = module.split('On successful completion of this course, students will be able to: ')
        if len(course_objectives)>1: #avoid empty strings

            #Module title
            title = module.split('\n')[0]

            #Module objtectives
            objectives = course_objectives[1]
            objectives = objectives.split('Teaching Methods')[0]
            if (objectives[-4:]) =='/78 ':
                objectives = objectives[:-6]
            objectives = objectives.encode()
            objectives = objectives.decode()
            objectives = objectives.replace('\n',"")
            objectives = objectives.replace('. ',".")
            objectives = objectives.split('\uf0a7  ')[1:] #[0] is always empty because of the splitting
            for objective in objectives:
                row_list = [objective,title,"DS_60"]
                df.loc[len(df)] = row_list #because of 0 indexing we can write to new row at len(df)

    return(df)

# %%
df=extract_objective_df(pdf)

# %%
df.head()
# Out:
#                                            objective                module  \
# 0  understand the fundamental building blocks of ...  Advanced Statistics
# 1  analyze stochastic data in terms of the underl...  Advanced Statistics
# 2            utilize Bayesian statistics techniques.  Advanced Statistics
# 3  summarize the properties of observed data usin...  Advanced Statistics
# 4  apply data visualization techniques to design ...  Advanced Statistics
#
#   study_program
# 0         DS_60
# 1         DS_60
# 2         DS_60
# 3         DS_60
# 4         DS_60

# %%
def preprocess_for_bert(string):
    string = string.strip("\n.’:")
    string = string.strip("’")
    string = string.strip("\\n")
    string = string.replace("/"," ")
    return(string)

# %%
k21 = pickle.load(open('../Experiments/k21.sav', 'rb'))
objectives = []
model = SentenceTransformer('paraphrase-MiniLM-L6-v2')
for o in df['objective'].to_list():
    objectives.append(preprocess_for_bert(o))
embeddings = model.encode(objectives)
clusters =  k21.predict(np.array(embeddings.tolist()))
df['clusters']=clusters

# %%
df
# Out:
#                                             objective  \
# 0   understand the fundamental building blocks of ...
# 1   analyze stochastic data in terms of the underl...
# 2             utilize Bayesian statistics techniques.
# 3   summarize the properties of observed data usin...
# 4   apply data visualization techniques to design ...
# 5   evaluate model parameters using parameter esti...
# 6   create hypothesis tests to discriminate betwee...
# 7   analyze use cases and their requirements regar...
# 8      apply common metrics to evaluate predictions.
# 9   evaluate key performance indicators to asses p...
# 10  create monitoring tools that can be used to co...
# 11  understand common fallacies and how to avoid t...
# 12  identify current research trends and topics in...
# 13  outline a selected topic in the form of a writ...
# 14  explain relevant assumptions and design choice...
# 15  relate the chosen topic to comparable approaches.
# 16  name and describe potential applications for t...
# 17     know different machine learning model classes.
# 18  comprehend the difference between supervised, ...
# 19         understand common machine learning models.
# 20  analyze trade-offs in the application of diffe...
# 21  appropriately choose machine learning models a...
# 22  comprehend the fundamental building blocks of ...
# 23              understand concepts in deep learning.
# 24  analyze the relevant deep learning architectur...
# 25                       create deep learning models.
# 26  utilize alternative methods to train deep lear...
# 27     understand current data science methodologies.
# 28  devaluate the quality of the data used in data...
# 29                 create new features from raw data.
# 30                apply feature selection techniques.
# 31  make predictive models using data science tech...
# 32  identify common fallacies and know how to avoi...
# 33  identify the different types and sources of data.
# 34            understand different database concepts.
# 35                     build new database structures.
# 36  evaluate various data storage frameworks w.r.t...
# 37  analyze which data format to use for a given p...
# 38  create a distributed computing environment for...
# 39  evaluate different manufacturing methods again...
# 40  define and design modern additive techniques i...
# 41  assess and estimate the impact of current tren...
# 42  apply  modern  processes  like  rapid  prototy...
# 43  explain and recognize the main components of a...
# 44  distinguish the sensor solutions for a self-dr...
# 45  model and implement a simple motion control sy...
# 46  manage the main communication protocols to ret...
# 47  reflect on the social impact of self-driving c...
#
#                                                module study_program  clusters
# 0                                Advanced Statistics          DS_60        11
# 1                                Advanced Statistics          DS_60        11
# 2                                Advanced Statistics          DS_60        11
# 3                                Advanced Statistics          DS_60        11
# 4                                Advanced Statistics          DS_60        15
# 5                                Advanced Statistics          DS_60        11
# 6                                Advanced Statistics          DS_60        11
# 7                            Use Case and Evaluation          DS_60        17
# 8                            Use Case and Evaluation          DS_60        11
# 9                            Use Case and Evaluation          DS_60        17
# 10                           Use Case and Evaluation          DS_60        11
# 11                           Use Case and Evaluation          DS_60        18
# 12           Seminar: Current Topics in Data Science          DS_60        13
# 13           Seminar: Current Topics in Data Science          DS_60        18
# 14           Seminar: Current Topics in Data Science          DS_60        18
# 15           Seminar: Current Topics in Data Science          DS_60        11
# 16           Seminar: Current Topics in Data Science          DS_60        17
# 17                                  Machine Learning          DS_60        16
# 18                                  Machine Learning          DS_60        16
# 19                                  Machine Learning          DS_60        16
# 20                                  Machine Learning          DS_60        11
# 21                                  Machine Learning          DS_60        16
# 22                                     Deep Learning          DS_60        16
# 23                                     Deep Learning          DS_60        16
# 24                                     Deep Learning          DS_60        16
# 25                                     Deep Learning          DS_60        16
# 26                                     Deep Learning          DS_60        16
# 27                     Case Study: Model Engineering          DS_60        13
# 28                     Case Study: Model Engineering          DS_60        13
# 29                     Case Study: Model Engineering          DS_60        15
# 30                     Case Study: Model Engineering          DS_60        16
# 31                     Case Study: Model Engineering          DS_60        11
# 32                     Case Study: Model Engineering          DS_60        18
# 33                 Big Data and Software Engineering          DS_60        15
# 34                 Big Data and Software Engineering          DS_60         7
# 35                 Big Data and Software Engineering          DS_60         7
# 36                 Big Data and Software Engineering          DS_60        15
# 37                 Big Data and Software Engineering          DS_60        15
# 38                 Big Data and Software Engineering          DS_60         3
# 39  Smart Manufacturing Methods and Industrial Aut...         DS_60        11
# 40  Smart Manufacturing Methods and Industrial Aut...         DS_60         3
# 41  Smart Manufacturing Methods and Industrial Aut...         DS_60         8
# 42  Smart Manufacturing Methods and Industrial Aut...         DS_60         3
# 43                        Applied Autonomous Driving          DS_60         3
# 44                        Applied Autonomous Driving          DS_60        11
# 45                        Applied Autonomous Driving          DS_60         3
# 46                        Applied Autonomous Driving          DS_60         3
# 47                        Applied Autonomous Driving          DS_60        18

# %%
missing = []
for i in range(0,21):
    if i not in clusters:
        missing.append(i)

# %%
print(missing)
# Out:
# [0, 1, 2, 4, 5, 6, 9, 10, 12, 14, 19, 20]
