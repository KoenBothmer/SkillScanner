# %%
import requests
from bs4 import BeautifulSoup
import nltk
import pickle
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize
import numpy as np
import pandas as pd
from datetime import datetime
from langdetect import detect
import os

# %%
df = pd.read_csv('df_toy.csv')
dir = r'\requests'

# %%
df.head()
# Out:
#    Unnamed: 0                          dt  \
# 0           0  2021-08-08 21:01:03.303868
# 1           1  2021-08-08 21:01:09.824428
# 2           2  2021-08-08 21:01:18.030788
# 3           3  2021-08-08 21:01:20.651507
# 4           4  2021-08-08 21:01:27.135797
#
#                                                  url  \
# 0  https://se.indeed.com/viewjob?jk=b0669075c820856d
# 1  https://se.indeed.com/viewjob?jk=dbfe7d7c087065d7
# 2  https://se.indeed.com/viewjob?jk=841a8fdd1bb00f2f
# 3  https://se.indeed.com/viewjob?jk=88c25a48d2da8a7a
# 4  https://se.indeed.com/viewjob?jk=1b4b8ee005f06350
#
#                               title            location country  \
# 0                   Data Scientist      Jobba hemifrån       se
# 1  Data Scientist, Search Insights           Stockholm       se
# 2            Junior data scientist     411 21 Göteborg       se
# 3                   Data Scientist    118 72 Stockholm       se
# 4                   Data Scientist               Solna       se
#
#                                            full_text  \
# 0  About us\n\nHere at Mavenoid, we are building ...
# 1  Data, Research & Insights\nData Science\nThe P...
# 2  Utilifeed is a rapidly expanding startup with ...
# 3  AI Data scientistLocation: Stockholm, SwedenDi...
# 4  Currently, we are looking for a talented data ...
#
#                                        list_elements
# 0  ['Collaborate with stakeholders and other engi...
# 1  ['\nExperimentation strategy including AB test...
# 2  ['\nImproving pour data ingestion pipeline, we...
# 3  ['Proven experience in Machine Learning (ML) a...
# 4  ['\nYou have a start-up mentality, with delive...

# %%
df=df.drop(["Unnamed: 0"], axis = 1)

# %%
def request_to_row(request):
    with open(r'requests\\'+ request) as file:
        text = file.read()
        soup = BeautifulSoup(text)  
        full_text = soup.find("div",{"id": "jobDescriptionText"}).text
        if(detect(full_text) != 'en'):
            print(full_text[0:50]) #testing
            return 
    
        timestamp = None
        content = []
        title_location = soup.find("title").text
        title = title_location.split("-")[0]
        location = title_location.split("-")[1]
        url = soup.find_all("meta", {"id": "indeed-share-url"})
        url = str(url[0])[15:-25]
        
        country = url[8:10]

        list_elements = []
    
        divs = soup.find_all("div",{"id": "jobDescriptionText"})
        for div in divs:
            uls = div.find_all("ul")
            for ul in uls:
                for li in ul.find_all('li'):
                    list_elements.append(li.text)
    return [timestamp,url,title,location,country,full_text,list_elements]

# %%
foo = None

# %%
foo = pd.DataFrame(columns = ["dt","url","title","location","country","full_text","list_elements"])
for filename in os.listdir(dir):
    row_list = request_to_row(filename)
    foo.loc[len(foo)] = row_list
df_ = df.append(foo)
# Out:
# CRIF, prestigioso ed innovativo Gruppo internazion
# Wil je deel uitmaken van zeer ervaren en gemotivee
# CONTEXTE ET MISSION
# Nous recrutons un/une Ingénieu
# Envie de contribuer à construire l’aéroport de dem
# Código: Data Governance
# Publicada el: 26/07/2021
# U
# Die ADEAL Systems GmbH (ADEAL = Agile Data Enginee
# You are an experienced Data Scientist and are sear
# Ben je klaar voor een volgende stap in je carrière
# Vos missions au quotidien
# Au sein de la direction
# Comment quelque chose que vous ne voyez pas peut a
# Description du poste
# Crédit Agricole, Agir chaque
# Why We Work at Dun & Bradstreet
# We are at a transf
# Hallo uitstekende SENIOR DATA SCIENTIST!
#
# Zou jij
# L'IRCCS Istituto Ortopedico Galeazzi sta cercando
# HISPAVISTA es un grupo de puntero en el sector dig
# Vi satser knallhardt på elektrifisering, og er all
# Société ACM GIE
#
# Nature du contrat CDI Référence A
# Messtechniker / Data Scientist (w/m/d)
# 29.07.2021
# Junior Data Scientist – Roma
# Management Consulting
# Over deze vacature Op de afdeling Debiteurenmanage
# Mach mit uns was GROßES!Keine Lust, nur ein Rädche
# Eskimoz
# L’Agence Eskimoz, spécialisée en référence
# Sede: Italia, Lazio, Roma
#
# Settore: Informatica
#
#
# Für den weiteren Ausbau unseres AI Teams innerhalb
# laufende Analyse von Kostenstellen/-arten
# laufende
# Senior Data Scientist / Engineer (w/m/x)
# Bist du d
# Description du poste
# CDD 5 mois- En tant que Data
# Data Scientist Python y/o R
# ¿Eres una persona que
# Freelancer Projekt -
# Für einen unserer Großkunden
# Über Uns
#
# In den letzten drei Jahren hat sich Stac
# Data Scientist, Helsinki
#
# Voit tulla meille työsuh
# WEMOOV RECRUTEWemoov est une Startup dynamique qui
# Bei smartclip gestalten wir die Zukunft der Fernse
# Offres
# Diplôme requis (offre)
# Master
# Service(s)
# Do
# PROPOSITION DE POSTE / PARIS, FRANCE
#
# DATA SCIENTI
# Algorhythm is een jong en dynamisch bedrijf met ee
# A proposCastle Bee est une société spécialisée dan
# Les données sont le nouvel or, et nous sommes en q
# Dans le cadre de notre développement, nous recherc
# Procruitment AB är en karriärbyrå som förenar attr
# Hoe
# Door het toepassen van de nieuwste data scienc
# Contexte
# La branche Famille est l’une des quatre c
# A área de Data Science dedica-se à análise e model
# Tools
# Python
# Keras
# Spark
# Scala
# KNIME
# Tableau
# Gehal
# Description du poste
# Crédit Agricole, Agir chaque
# Pour renforcer notre activité Solution Software, n
# Die WALTER GROUP mit mehr als 4.400 Mitarbeiterinn
# Sie wollen Aufbauarbeit in einem dynamischen Analy
# Ben jij klaar om je collega’s mee te nemen in het
# ¿Quiénes somos?
#
# Somos una startup formada por un
# Siamo alla ricerca di un candidato da inserire all
# Description
# Sur un marché de plus en plus concurre
# Empresa española de analítica de datos sanitarios
# Fonction : Recueil et extraction de sources de don
# Descrizione del lavoro
# Siamo alla ricerca, per la
# Offerta numero: PO00124351
#
# Luogo di lavoro: PISTO
# Notre équipe d’ingénieurs de haut niveau est animé
# Du hast Lust bei einem Greenfield-Projekt in Nürnb
# STAGE DATA SCIENTIST (H/F) (NUMÉRO DE L'EMPLOI : P
# Peut-être avez-vous dans votre dressing des vêteme
# Sei pronto ad entrare in una azienda dinamica, inn
# Contractvorm
#
# Onbepaalde duur
#
# Werkregime
#
# Voltijd
# Hauptsache
#
# Künstliche
#
# Intelligenz
#
# zieht dich an
# Business Intelligence und Data Science sind deine
# L'entreprise
# QUI SOMMES-NOUS ?
#
# Le Groupe MisterMe
# Bookarang is een jong technologiebedrijf (scale-up
# Arbetsuppgifter
#
# Analytics är ett satsningsområde
# ¿Te apasiona la tecnología y te gustaría formar pa
# Tillsammans. Det är så vi jobbar på Gaia. Vi plock
# Position Description:
# CGI leder digitaliseringen a
# What impact will you make?
#
# YOUR OPPORTUNITY
#
# Il p
# Als junge Performance Marketing Agentur mit Haupts
# Fondata nel 2008, Facile.it è la Web Company leade
# Gan Assurances a engagé un vaste plan de transform
# Innovative Technologien und Lösungsansätze
# ‘Off-De
# Pour renforcer notre pôle Big data, nous recrutons
# L'entreprise
#
# Description de l'emploi
# En tant qu’a
# Wir von MONDAY.ROCKS haben ein digitales Team-Inst
# Rôle et Mission: Plus que jamais, la Data est au c
# De digitalisering van de maatschappij zorgt voor d
# Laakirchen Berufseinstieg/Absolvent
# Ihre Aufgaben
#
# Buscamos un científico de datos ambicioso y orient
# Elämä on tehty elettäväksi. Siksi on Fennia.
# Etsim
# Data Scientist (m/w/d) | Computer Vision | B2B | S
# Al meer dan 60 jaar produceert onze klant, een int
# Wij zoeken jou als Data Analyst (Commercial Insigh
# WIEN
# Aufgaben
# Du verantwortest maßgeschneiderte En
# Opleidingsniveau WO
# Afdeling ICT
# Carrièreniveau Pr
# Om onze ambitieuze toekomstplannen te realiseren z
# Descriptif du poste:
# Au sein d’une équipe passionn
# Fakt ist:
# Wir sind auf der ganzen Welt tonangebend
# KOMPETENS
# Data/IT
# PUBLIKATIONSDATUM
# 4 Aug 2021
# LAN
# Wir sind ein schlagkräftiges Team datengetriebener
# Job Profile
#
# Da Analista CRM sarai responsabile di
# Data scientistAdchieve is een award-winning softwa
# Acteur majeur de l’assurance en France et forte de
# The Dutch language is mandatory for this position.
# Adora ICT dal 2005 offre un’ampia gamma di prodott
# SwiraData Consulting cerca AI DATA SCIENTISTS, per
# Il candidato ideale ha una seniority di almeno 2 a
# Descriptif du poste:
# ## Contexte du poste
# L'entrep
# Passione per l'Innovazione. Considerazione per i P
# Nice-business Consulting Oy:n (Nico) on it-alan re
# Eurecat Centro Tecnológico de Cataluña
# CATALÀ
#
# Eur
# Siamo alla ricerca di un Ingegnere Informatico o L
# Die TPN2 ist ein IT-Dienstleistungsunternehmen, we
# Tu es Data Scientist
# et tu souhaites relever de no
# Ben jij sterk in het maken van rapportages en anal
# willkommen bei OraylisGestalte als Data Scientist
# Rattaché(e) au service Data Intelligence, vos prin
# Mosaique Headhunting AS
# Vil du hjelpe bedrifter ti
# Motion Analytica è una start-up innovativa con com
# A1 ist viel mehr als nur ein Telekommunikationsunt
# Gedesco Services Spain es la mayor Fintech (de fin
# Entra nel nostro mondo.
#
# Trasforma insieme a noi.
#
# Descrizione
# Wellnet, azienda del gruppo Prismi S.p
# Die IWD market research GmbH ist eines der führend
# Functie inhoud
#
# Voor onze opdrachtgever, internati
# Bedrijfsomschrijving
# We believe in the power of in
# DATA SCIENTIST H/F
# MARSEILLE (13) – WITMONKI SAS
# P
# Offres
# Diplôme requis (offre)
# Master
# Service(s)
# Do
# QUI SOMMES-NOUS ?
# Situé dans un espace de co-worki
# Bli kjent med Itera
# MAKE A DIFFERENCE
#
# I Itera del
# Au sein du département Sciences des Données et Inc
# Il candidato ideale è laureato o laureando in mate
# Seit mehr als 130 Jahren legen Versicherte in Deut
# Descriptif du poste:
# Construire un pipeline de dat
# GERI HDP S.r.l. - Milano - www.gerihdp.it
#
# GERI HD
# Tu es prêt à relever de nouveaux défis et à apport
# Siemens Mobility er verdens ledende leverandør av
# Vi söker dig som, liksom oss, älskar att jobba med
# Starter, Kontich, Gent, Wavre
# Ben je analytisch in
# Description de la fonction
#
# Selor, le bureau de sé
# I Vipps jobber vi hver dag med å gjøre alle type b
# Prestigiosa azienda informatica, leader italiano d
# Vi søker DEG som ønsker å jobbe med datadrevet bes
# Data Scientist/Científico de Datos en Madrid.
# Nece
# Ort:
#  Hamburg
# Einstellungsart:
#  Vollzeit
# Dauer:
#  U
# Rattaché(e) à la Direction Générale Exécutive de M
# Siamo Spindox: energia pura, intelligenza e passio
# Convaincu que les hommes et les femmes sont la ric
# CONTRAT :CDI
# TEMPS DE TRAVAIL :Temps plein
# EXPÉRIE
# EnvironnementFintech interne du groupe Crédit Agri
# Unsere Kund:innen in Dialog mit ihren Kund:innen z
# Die LGT ist die weltweit grösste Private Banking u
# Wij bieden jou:
# Een persoonlijk ontwikkelplan! Je
# Are you driven by Technology?
# Se sim, é na Red IT
# Stiamo cercando un Data Scientist esperto e appass
# Description de l'entreprise
# Depuis plus de 35 ans,
# Data Scientist (m/w/x) | Praktikum | 3 MonatePrakt
# Du findest Dich hier wieder?Für Dich sind Machine
# E.ON är övertygade om att du som är junior, nyfike
# Für unseren Standort in Tübingen suchen wir für de
# Opportunità
#
# Questa è un’interessante opportunità
# Die INTENSE AG steht seit über 20 Jahren für erfol
# Description de l'entreprise
#
#
# Le Groupe BPCE, issu
# Nell’ambito del proprio sviluppo e crescita, l’azi
# Localyse is op zoek naar een Data Analist om haar
# Data Scientist F/H
#
#
#
# Votre mission :
# Intégrez à u
# Oferecemos
# Acesso a uma comunidade de mais de 400
# Our offer
# Capgemini Engineering i Dalarna kombiner
# Siamo alla ricerca di un/una Data Engineer da inse
# Le Data Scientist est responsable de la gestion et
# Quand vous achetez un pull, un médicament ou un pr
# Je werkt op autonome wijze mee aan data projecten.
# Bundesweit
# Über uns
#
# Die PTA ist eine familiengefü
# Supportare l'area ricerche GEO Marketing nell'impl
# Revolutionize 3D printing with us
# DATA SCIENTIST (
# A INTEGER, uma empresa de consultoria na área das
# 100%, Wien
# Du willst in einem Team arbeiten, das a
# I Atea brenner vi for livslang læring. Gode verdie
# Unternehmensbeschreibung
# Mit der Schalungskompeten
# Synergie Italia Spa, filiale di Siena, seleziona p
# Sede: Italia, Lazio, Roma
#
# Settore: Informatica
#
#
# Als (Junior) Data Scientist - Marketing ontwikkel
# Note! You may also apply in English.
# Talenom Oyj o
# Analyste de données/Data Analyst*Technologie (data
# (Junior) Data Scientist (m/w/d)
#
# BIOTRONIK ist ein
# DEIN UMFELD UND TEAM
#
# Du glaubst an die Kraft von
# Offres
# Diplôme requis (offre)
# Master
# Service(s)
# Se
# Au sein de la direction "Vision Client, Big Data e
# HESPLORA ricerca candidati da inserire nel proprio
# Wat wij bieden
# een groep gepassioneerde vakgenoten
# Vi ser etter deg som har et brennende engasjement
# Fondée en 2016 par deux professionnels de la Finan
# Poste
#
# Au sein du département Data Science et Inte
# Techyon: Information Technology Recruitment Expert
# En pfsGROUP somos expertos en identificar y genera
# Die Fachhochschule Kärnten bietet in den Bereichen
# Als data scientist / AI-engineer binnen Mediaan, m
# Jobaanbod
# Vereist diploma (aanbod)
# Master
# Dienst(e
# CHECK24 ist eines der führenden Online-Unternehmen
# Wat ga je doen
#
# Wil jij een bijdrage leveren aan d
# Dans le cadre du développement des activités digit
# Castra Syd fortsätter vår tillväxtresa, där vi på
# Right er et konsulentselskap som startet i 2009. S
# Sobre a Empresa︎
# A LCG procura apresentar uma prop
# Ben jij (bijna) klaar met je (bèta)-studie, en wil
# Vous bénéficiez d’une expérience significative dan
# Belfius zoekt een Data Scientist met een passie vo
# Leuk je te ontmoeten…
#
# Wij zijn i2i, een jonge, am
# Als onafhankelijk onderzoeks- en consultingbureau
# Funmed är en svensk MedTech-startup och Europas st
# Unternehmen befinden sich weltweit in einem digita
# Varje år fattar Försäkringskassan 21 miljoner besl
# Entra nel nostro mondo.
#
# Trasforma insieme a noi.
#
# SGT está buscando un/a DATA SCIENTIST para nuestra
# Als Data Scientist (m/w/d) bei der Alcedis arbeite
# Data Scientist (w/m/x)
# Begleiten Sie die digitale
# Delft/Utrecht, zie bijzonderheden
# €3279 - €5039 (s
# De afdeling Customer Data Analytics heeft als miss
# Die Allianz Versicherungs-AG ist mit mehr als 125
# Vår misjon er å redde verden fra irrelevant kommun
# Como é o Cientista de Dados Ser Caetano?
# – É proat
# Unsere Mission:
#
# Shopper. Data. Knowledge. Actions
# Sie suchen nach einer neuen Herausforderung in der
# Org. nr: 988388874 Stillingsident: 4414520591 Pres
# La Setting S.p.A. è un System Integrator in ambito
# Présentation de l'entreprise
# Rejoindre La Banque P
# AUF DER SUCHE NACH EINEM TECHNIKJOB AB HERBST 2021
# QUI SOMMES-NOUS ?
# L’activité avionique rassemble 1
# Ønsker du å jobbe for et av landets ledende teknol
# Cerved è la data driven company italiana.
#
# Aiutiam
# Requisiti tecnici:
# Ottima conoscenza di Python
# Ott
# Wat ga je doen?
# Als Senior Data Scientist draag ji
# Siemens Mobility er verdens ledende leverandør av
# Als Data Scientist ben je verantwoordelijk voor he
# Descripción:
# En Grupo Oesía ofrecemos servicios de
# Netherlands
# Heb je ervaring in de rol van Scientis
# En jobb i DI kan nesten ikke beskrives, den maÌŠ o
# CHI SIAMOPrograms & Projects Consulting S.r.l., so
# Publish Date: Jul 28, 2021
#
# Location:
# Milano, Lomb
# Direct bijdragen aan een duurzamer energiesysteem
# Tehtävä
# AI Specialist
# Sijainnit
# Koko Suomi
# Haku al
# Weather Technology op het allerhoogste niveau
# Meer
# Statut : Employé de l'État
# Qui recrute ?
#
# La missi
# En rejoignant l’équipe Data & Digital Marketing au
# Vill du arbeta på ett innovativt bolag där du får
# LEOSPHERE, entreprise française de haute technolog
# Arbetsuppgifter
# Behovet av Data Engineers är stort
# ITrust est une société d’expertise en sécurité inf
# Innovatief, verbindend en LEF! Dat is Asset.Insigh
# Avec Auchan, révélez vos talents...
# Nous rejoindre
# Aufgaben, die mich erwarten
# aktives Mitgestalten d
# Ansök
# MCA Sweden söker IT-branschens vassaste kons
# Bozen
# Für die Entwicklung aufregender neuer Produk
# Vi søker DEG som ønsker å jobbe med datadrevet bes
# Buscamos un perfil de Actuario/a con experiencia e
# Data Scientist
# Data: 3-ago-2021
# Città: Milano
# Soci
# Descripción:
# ¿Qué buscamos? En M2C estamos buscand
# Die TPN2 ist ein IT-Dienstleistungsunternehmen, we
# Für diese Position sind sehr gute Deutsch- und/ode
# Westhouse è una società leader che opera nel campo
# ENTREPRISE
# Description : Cette start-up est spécia
# Descripción de la empresa
# ¿Qué es Unlimiteck?
# Unli
# Functieomschrijving
# “Ik maak analyses voor allerle
# Au sein de la Direction Marketing, l'objectif prin
# Als data scientist hou je van complexiteit en ben
# CONTEXTE ET MISSION
# Vous souhaitez évoluer dans un
# #miasanhammer – das ist die Samhammer AGWir, die S
# Oferecemos
# Acesso a uma comunidade de mais de 400
# Descriptif de la société :
#
# Unilever est un leader
# Startup i praksis. Knowit Insight, fra 1-20 ansatt
# La LOG.IT s.r.l., società specializzata nell’integ
# Nell’ottica di ampliare il suo organico, Sisal è a
# Vos responsabilitésEn tant que Data Scientist, vou
# Desarrolla una carrera profesional con nosotros
# ¡M
# Zürich
# Unsere IT-Lösungen machen unsere Kunden bes
# Cegeka is één van de leiders op het vlak van IT Co
# NHAZCA S.r.l., Startup della Sapienza Università d
# Als Data Scientist bist du Teil unseres Data-Scien
# Sopra Steria - utsedd till en av topp-15 bästa arb
# ManpowerGroup cerca per importante azienda plurilo
# CogniData recherche des consultants Data Scientist
# Au sein de l'équipe Cocoon de CACIB spécialisée da
# Dettagli
#
# Publication date
#
# 06/08/2021
#
# Location
#
#
# Unser Klient ECBM ist eine junge, dynamische IoT-
# Responsabilità:
#
# Raccogliere grandi quantitativi d
# Descrizione
# Wellnet, azienda del gruppo Prismi S.p
# Ekimetrics est leader européen en data science ave
# Die Avobis Gruppe mit rund 300 Mitarbeitenden und
# Su misión será la de identificar oportunidades y m
# Respeito, Precisão, Criatividade e Sentido Crítico
# Offriamo Stage finalizzato all'assunzione in un co
# Challenges réguliers
# Espaces de détente
# Couverture
# Descrizione dell'azienda
# AutoHero, l'innovativa co
# Right er et konsulentselskap som startet i 2009. S
# L'IRCCS Istituto Ortopedico Galeazzi sta cercando
# Localização
# Lisboa
# Tipo de Oportunidade
# Full-Time
#
# Bienvenue chez Maisons du Monde !
# Chez nous c’est
# Description de l'offre
#
# NEXTON, leader du conseil
# Overview:
#
# Ønsker du å kickstarte karrieren din so
# Data Scientist / Researcher für NLP
# Sie haben bere
# L'IRCCS Istituto Ortopedico Galeazzi sta cercando
# Descriptif du poste:
# Sous la responsabilité du Res
# Klar for en utfordring? Bli med i vårt stordatatea
# Wir sind mit 16 jö Partnern und 4 Millionen jö Mit
# Unser Kunde fördert und vermarktet Öl und Gas, sow
# Vi ser ett ökat behov av data science- och AI-tekn
# Data Scientist/ Data Analyst Health Research bei F
# Right er et konsulentselskap som startet i 2009. S
# Are you driven by Technology?
# Se sim, é na Red IT
# Description entreprise :
# Free Mobile est un opérat
# Alternance en contrat d’apprentissage
# Nous recherc
# Van idee via data naar antwoorden
# Koopgedrag voors
# DATA SCIENTIST
# Il candidato ideale ha una seniorit
# Description du poste
# Les Marchés de Capitaux couvr
# Seleccionamos una persona amante de los retos, con
# Ricerca, analisi e armonizzazione dei dati di sint
# Développeur Back-end / Data Scientist F/H Dans le
# Unternehmensbeschreibung
# Bei Bosch gestalten wir Z
# solicon IT ist ein junges innovatives österreichis
# ManpowerGroup cerca per importante azienda plurilo
# Castle Bee est une société spécialisée dans la val
# Unternehmensbeschreibung
# Mit der Schalungskompeten
# Eurecat Centro Tecnológico de Cataluña
# CATALÀ
#
# Eur
# Trives du med tall, data og programmering? Kunne d
# Jouw rol
# Ixor is op zoek naar een Junior Data Scie
# Fater, è un'azienda italiana, joint venture parite
# Fra og med 1. mai 2021 styrker Norconsult satsinge
# Sie begeistern sich für komplexe Datenstrukturen u
# Als data scientist / AI-engineer binnen Mediaan, m
# Descripción del puesto
#
# El puesto tiene como misió
# Locatie: Hasselt
# Ons team
#
# ACA’s Innovation Lab is
# Description de l'entreprise
# Depuis plus de 35 ans,
# Référence de l’offre
# 210007UN
# Type de contrat
# CDI
#
# CONTRATO Ref: 148/2020.
#
#
#
# Requisitos para partici
# Datagedreven beslissingen zullen onze economie en
# Jakala è la prima società martech italiana che off
# Belgium, Olen
# Group R&D
# Research & Development
# Ove
# PROPOSITION DE POSTE / COURBEVOIE, FRANCE
#
# DATA SC
# Qui sommes-nous ?
# OpenClassrooms est une entrepris
# La croissance très importante du volume des donnée
# Micropower Group befinner sig i stark tillväxt och
# Il candidato ricoprirà il ruolo di Junior Data Eng
# Grant Thornton België is lid van Grant Thornton in
# Descriptif du poste:
# Au sein de la Direction Digit
# Talenom Oyj on ketterä ja edistyksellinen tilitoim
# Ben jij een data-expert, heb je kennis van en erva
# Vad roligt att du är nyfiken på oss! Förhoppningsv
# Aus Zahlen Erfolg ableiten beim Marktführer!Mit un
# A área de Data Science dedica-se à análise e model
# Oferecemos
# Acesso a uma comunidade de mais de 400
# Zum Aufbau des innovativen Bereichs Business Intel
# Descrizione Attività
# Capgemini Engineering è alla
# Vill du vara med och utveckla ett kund- och datadr
# Nos interventions :
#
# L'objectif de nos missions es
# Erschaffe mit uns digitale Lösungen für die Zukunf
# ¿Te interesa el sector AdTech? ¿Tienes experiencia
# Een werkplek waar je zelf het heft in handen mag n
# Over de vacature Ben jij in het bezit van een mast
# Die WALTER GROUP mit mehr als 4.400 Mitarbeiterinn
# Wat kan je verwachten van een job als Manager Data
# Line of Service
# Advisory
# Industry/Sector
# Not Appli
# Wir sind eine Neugründung im Umfeld des Digitalhub
# Au sein de la Direction Digital de la Direction Cl
# Siamo alla ricerca, per la nostra sede di Milano,
# Entra nel nostro mondo.
#
# Trasforma insieme a noi.
#
# Fondé en 2011, Carenity est le 1er réseau social d
# Qui sommes-nous, quelle est notre mission et notre
# Als Data Scientist bij Stratics ontwikkel je doelg
# Multinacional
# Carrera Profesional
# Acerca de nuestr
# Axpo Italia SpA, consociata del Gruppo Svizzero Ax
# Le Groupe Carrefour est le leader de la grande dis
# FABDEV est une jeune entreprise innovante en forte
# Polly, Lendra, Lex saranno il tuo pane quotidiano.
# La Fondazione LINKS è stata fondata nel 2016 sfrut
# Oss, Noord-Brabant
# Squadra Machine Learning Compan
# 01
# Sede
# Roma / Milano
# 02
# Livello
# Junior / Senior
# P
# No Hurb, nossa equipe de Data Science combina apre
# Vi är redo för att leta kandidater till Traineepro
# Das European Site & Verbund Management entwickelt
# ONZE VISIE
#
# Deep Customer Connect is een nieuw tea
# Offres
# Diplôme requis (offre)
# Master
# Service(s)
# Fi
# À propos
#
# Ipsos est le leader en France des études
# Bouvet Bergen har et av Bergens sterkeste konsulen
# Fun Miles voert een succesvol multi-partner loyali
# Vi startade Signific för att kunna lösa världens m
# O mundo está mais ligado do que nunca e o ritmo da
# Job-ID: V000003949
# Einsatzort: Linz
# Zeitpunkt: ehe
# 7Learnings ist ein Technologie- und Softwareuntern
# Jouw uitdaging als Data Scientist
#
# Ben jij starten
# Werde Teil unseres agilen Digital Supply Chain Tea
# Descriptif du poste:
# Nous recrutons un/une Ingénie
# Com 29 anos de experiência, a Rumos Serviços atua
# Wir sind ein cooles Unternehmen, mit einem starken
# Du siehst in einem Pressetext nicht nur die geschr
# EY France, certifié à nouveau « Great Place to Wor
# Creación, análisis y gestión de bases de datos
#
# Co
# Descrizione dell'azienda
# Noicompriamoauto.it è lo
# Descrizione attività:
# La crescita esponenziale dei
# THE OPPORTUNITIES ARE ENDLESS WHEN YOU ARE FEARLES
# Basé à Cysoing (59),Ducatillonest une société de V
# Description
# Sur un marché de plus en plus concurre
# Liebst du es mit grossen Datenmengen zu arbeiten?
# Die Zukunft gehört dem E-Commerce. Und dir! Als Da
# Per potenziare il team di Data Science stiamo cerc
# Stroopler [nom | collaborateur de Stroople]. Vous
# Arbetsuppgifter
#
# Behovet av Data Engineers är stor
# De strijd aangaan met complexe problemen? Daar hou
# Descriptif du poste:
# Au sein de la Direction des p
# Acteur majeur de l’assurance en France et forte de
# Bewerben
# Für diese interessante Aufgabe suchen wir
# Niveau d’expérience : 2-5 ans
# Disponibilité : 3 mo
# AssurOne, entreprise du groupe PRÉVOIR et acteur m
# Actualmente buscamos un Data Scientist que se inco
# Descrizione
# Per la nostra sede di Milano siamo all
# Wij zoeken jou als Data Scientist
# Voor ons Strateg
# Vilka är vi på B3 Commit? Vi är inget vanligt kons
# Imaginez demain…
#
# Au sein d’une équipe pluridiscip
# Unternehmensbeschreibung
# Möchten Sie Ihre Ideen in
# Descrizione
# Il candidato ideale ha una seniority d
# Il candidato verrà inserito nell’area IT della div
# DESCRIPTION DE L'ENTREPRISE
# Depuis 1995, nous nous
# Ihre zukünftige Rolle:
# Unterstützung des Teams bei
# Du interessierst dich für High-Tech?Wir sind ein g
# Imagínate lo que podrías hacer con 1500 Terabytes
# Is Machine Learning voor jou meer dan een buzz wor
# Rejoignez une équipe ambitieuse et dynamique. JOSK
# DESCRIPTIF DU POSTE
#
# En tant que Data Scientist vo
# JAC’EM IT est une agence de travail temporaire et
# Beschik jij over een brede analytische toolset om
# Vi på Menigo tror att den goda måltiden har krafte
# Gratuliere - du hast hiermit den ersten Schritt zu
# Unternehmensbeschreibung
# Möchten Sie Ihre Ideen in
# Für diese Position sind sehr gute Deutsch- und/ode
# the tean® ist eine international agierende Digital
# Métier
#
# Marketing / Communication
# Titre du poste
#
#
# Per ampliamento del nostro team interno ramo assic
# Wie zijn we?
# Bij AE - Architects for business en I
# ei3 bietet Lösungen für das "Industrielle Internet
# A EDP é uma empresa global de energia, que lidera
# Vos missions au quotidien
# Nous recherchons pour no
# Die datasolut GmbH ist ein junge KI-Beratung aus K
# ¿Estás preparado para aplicar tus conocimientos en
# En tant que Marketing Data Scientist vous serez re
# Vi er på utkikk etter enda en Data Scientist til v
# Als Shiny Developer / Data Scientist werk je mee a
# Zum nächstmöglichen Zeitpunkt suchen wir an einem
# In Math&Sport siamo alla ricerca di persone intrap
# En tant qu’analyste GEO data , vous contribuez à l
# WIEN
# Aufgaben
# Nutze dein Know-how in Data Pipeline
# Fondata nel 2011, Facile.it è la Web Company leade
# L'entreprise
#
# Description de l'emploi
#
# Vous êtes a
# Als Senior Data Scientist – Retail Intelligence tr
# Voltijds Data Engineer/Scientist
# Computer and IT -
# NoA Ignite (tidligere Making Waves) er det største
# Die APG|SGA, Allgemeine Plakatgesellschaft AG ist
# FunctieomschrijvingPer direct zijn wij op zoek naa
# Innsbrucker Kommunalbetriebe AG Jobportal
# IKB - Sa
# Vos missions au quotidien
# Vous savez « faire parle
# Vacature Data Scientist
#
# Ben jij klaar voor een vo
# Der Fokus liegt auf der digitalen Transformation v
# Le groupe NRB est aujourd’hui une entreprise leade
# EY France, certifié à nouveau « Great Place to Wor
# Wil jij met de nieuwste technieken modellen ontwik
# Tu misión será dar soporte al equipo de Marketing
# 11 augustus 2021
# Data Scientist
#
# Om onze Corporate
# Vous ferez partie intégrante de l’équipe IT opérat
# En rejoignant l’équipe Data & Digital Marketing au
# Capgemini Engineering i Dalarna kombinerar personl
# Acteur majeur des télécoms et opérateur national d
# Quem Somos?
# Somos uma consultora portuguesa que pr
# Depuis 2004, I-care Group est le leader internatio
# Du arbeitest in Chur, The Circle/Zürich, St. Galle
# Nach einer intensiven Einarbeitungsphase arbeitest
# Desde Exceltic, buscamos un/una Data Scientist / M
# De laatste jaren heeft Stern een moderne digitale
# Unternehmensbeschreibungrheindata berät namhafte K
# A Axians é a marca do grupo Vinci Energies dedicad
# Supporto alle attività di progetto e gestione di r
# Offres
# Diplôme requis (offre)
# Master
# Service(s)
# In
# Standort: Wien | Stundenausmaß: Vollzeit oder Teil
# Meine Aufgaben
# Analyse, Optimierung und Weiterentw
# Desde K-LAGAN buscamos Senior Big Data Scientist p

# %%
len(df_)
# Out:
# 1637

# %%
df_.to_csv("df_europe")

# %%
df_dl=pd.read_csv('./datasets/data_scientist_united_states_job_postings_jobspikr.csv')
df_dl = df_dl.dropna(subset=['html_job_description'])
df_dl.head()
# Out:
#                 crawl_timestamp  \
# 8338  2019-09-03 16:29:36 +0000
# 8339  2019-09-03 16:29:57 +0000
# 8340  2019-09-03 15:36:16 +0000
# 8341  2019-09-03 16:31:44 +0000
# 8342  2019-09-03 16:32:31 +0000
#
#                                                     url  \
# 8338  https://www.indeed.com/viewjob?jk=0ff929240cbd...
# 8339  https://www.indeed.com/viewjob?jk=57d5bc547a93...
# 8340  https://www.indeed.com/viewjob?jk=9ba0c82d9eee...
# 8341  https://www.indeed.com/viewjob?jk=6b46936a0aad...
# 8342  https://www.indeed.com/viewjob?jk=2064635d106d...
#
#                                 job_title                     category  \
# 8338                       Data Scientist  Engineering-or-architecture
# 8339                       Data Scientist  Engineering-or-architecture
# 8340  Data Scientist/Engineer (HDF, NiFi)   Construction-or-facilities
# 8341                       Data Scientist  Engineering-or-architecture
# 8342                       Data Scientist  Engineering-or-architecture
#
#                                   company_name           city     state  \
# 8338                     Datatron Technologies  Mountain View        CA
# 8339                            3T Biosciences     Menlo Park        CA
# 8340   Novel Applications of Vital Information         Dulles  VA 20101
# 8341                                    4th-IR       New York        NY
# 8342  Social Science Research Solutions (SSRS)     Glen Mills        PA
#
#      country  inferred_city inferred_state  ...  \
# 8338      US  Mountain view     California  ...
# 8339      US     Menlo park     California  ...
# 8340      US            NaN       Virginia  ...
# 8341      US       New york       New york  ...
# 8342      US            NaN   Pennsylvania  ...
#
#                                         job_description   job_type  \
# 8338  We are looking for a Data Scientist to apply d...  Undefined
# 8339  CULTURE:\n\nWe’re committed to making a differ...  Undefined
# 8340  Data Scientist/Engineer (HDF, NiFi)\n\nLocatio...  Undefined
# 8341  We’re looking for intelligent, creative indivi...  Undefined
# 8342  SSRS Data Scientist\n\nSSRS, a leading data-dr...  Undefined
#
#      salary_offered job_board  geo            cursor contact_email  \
# 8338            NaN    indeed  usa  1567533631180639           NaN
# 8339            NaN    indeed  usa  1567533631641041           NaN
# 8340            NaN    indeed  usa  1567533632291934           NaN
# 8341            NaN    indeed  usa  1567533632358051           NaN
# 8342            NaN    indeed  usa  1567533632670111           NaN
#
#       contact_phone_number                           uniq_id  \
# 8338                   NaN  6de263f8e3b53f2cb3ad2f56df9b2d6f
# 8339                   NaN  03831abc643392c3fc07543f81a2031f
# 8340                   NaN  dc11fb4c640eb21e27754abd71430f41
# 8341                   NaN  363d6929ca85786a734812d0605df060
# 8342                   NaN  98dcc399714685995627bdf1e0d0dfca
#
#                                    html_job_description
# 8338  <div id="jobDescriptionText" class="jobsearch-...
# 8339  <div id="jobDescriptionText" class="jobsearch-...
# 8340  <div id="jobDescriptionText" class="jobsearch-...
# 8341  <div id="jobDescriptionText" class="jobsearch-...
# 8342  <div id="jobDescriptionText" class="jobsearch-...
#
# [5 rows x 22 columns]

# %%
df_dl=df_dl[["crawl_timestamp","url","job_title","inferred_city","job_description","html_job_description"]]#,axis=1)
df_dl.head()
#df_dl.columns = ['title','full_text','location']
countries = []
list_of_list_elements = []
for index, row in df_dl.iterrows():
    countries.append("us")
    soup = BeautifulSoup(row["html_job_description"])
    list_elements = []
    
    divs = soup.find_all("div",{"id": "jobDescriptionText"})
    for div in divs:
        uls = div.find_all("ul")
        for ul in uls:
            for li in ul.find_all('li'):
                list_elements.append(li.text)
    list_of_list_elements.append(list_elements)
df_dl["country"]=countries
df_dl["list_elements"] = list_of_list_elements
df_dl = df_dl.drop(["html_job_description"], axis = 1)
df_dl.columns = ["dt","url","title","location","full_text","country","list_elements"]
df_dl = df_dl.reindex(columns=["dt","url","title","location","country","full_text","list_elements"])

# %%
df_dl
# Out:
#                              dt  \
# 8338  2019-09-03 16:29:36 +0000
# 8339  2019-09-03 16:29:57 +0000
# 8340  2019-09-03 15:36:16 +0000
# 8341  2019-09-03 16:31:44 +0000
# 8342  2019-09-03 16:32:31 +0000
# ...                         ...
# 9994  2019-09-29 00:43:50 +0000
# 9995  2019-09-29 00:55:15 +0000
# 9996  2019-10-01 00:50:33 +0000
# 9998  2019-09-27 00:41:31 +0000
# 9999  2019-09-27 00:53:10 +0000
#
#                                                     url  \
# 8338  https://www.indeed.com/viewjob?jk=0ff929240cbd...
# 8339  https://www.indeed.com/viewjob?jk=57d5bc547a93...
# 8340  https://www.indeed.com/viewjob?jk=9ba0c82d9eee...
# 8341  https://www.indeed.com/viewjob?jk=6b46936a0aad...
# 8342  https://www.indeed.com/viewjob?jk=2064635d106d...
# ...                                                 ...
# 9994              https://stackoverflow.com/jobs/293326
# 9995              https://stackoverflow.com/jobs/271829
# 9996              https://stackoverflow.com/jobs/283895
# 9998              https://stackoverflow.com/jobs/283895
# 9999              https://stackoverflow.com/jobs/283895
#
#                                                   title       location  \
# 8338                                     Data Scientist  Mountain view
# 8339                                     Data Scientist     Menlo park
# 8340                Data Scientist/Engineer (HDF, NiFi)            NaN
# 8341                                     Data Scientist       New york
# 8342                                     Data Scientist            NaN
# ...                                                 ...            ...
# 9994  Siri - Embedded Data Scientist, Data Organization     Pittsburgh
# 9995                                     Data Scientist       Columbus
# 9996               Data Scientist, (Staff or Principal)    Santa clara
# 9998               Data Scientist, (Staff or Principal)    Santa clara
# 9999               Data Scientist, (Staff or Principal)    Santa clara
#
#                                               full_text country  \
# 8338  We are looking for a Data Scientist to apply d...      us
# 8339  CULTURE:\n\nWe’re committed to making a differ...      us
# 8340  Data Scientist/Engineer (HDF, NiFi)\n\nLocatio...      us
# 8341  We’re looking for intelligent, creative indivi...      us
# 8342  SSRS Data Scientist\n\nSSRS, a leading data-dr...      us
# ...                                                 ...     ...
# 9994  Job Summary: Would you like to play a part in ...      us
# 9995  Join Upstart and help build the future of cred...      us
# 9996  Data Scientist, (Staff or Principal) at realto...      us
# 9998  Data Scientist, (Staff or Principal) at realto...      us
# 9999  Data Scientist, (Staff or Principal) at realto...      us
#
#                                           list_elements
# 8338  [Selecting features, building and optimizing m...
# 8339  [\nBuilding, testing, and optimizing statistic...
# 8340  [U.S. Citizenship required, Must have current ...
# 8341                                                 []
# 8342  [Use machine learning methods (e.g., cluster a...
# ...                                                 ...
# 9994                                                 []
# 9995                                                 []
# 9996                                                 []
# 9998                                                 []
# 9999                                                 []
#
# [1599 rows x 7 columns]

# %%
df_full = df_.append(df_dl)

# %%
df_full = df_full.drop_duplicates(subset=['location','full_text'])

# %%
df_full.to_csv('df_full.csv')

# %%
len(df_full)
# Out:
# 2633
